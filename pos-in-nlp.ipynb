# %%
import spacy
nlp = spacy.load('en_core_web_sm')

# %%
# Text with Khaled's name
doc1 = nlp('''Khaled Ashraf, an AI engineer from Egypt, has worked on various projects in the field of machine learning. 
He completed the 'Deep Learning for Computer Vision' course on Udemy and has a deep passion for NLP and AI development. 
Khaled is known for his expertise in computer vision and is actively working on a Kaggle project to improve AI-based systems. 
In his spare time, he enjoys exploring new AI technologies and sharing knowledge with others.''')

# Loop through each token and print details
for token in doc1:
    print('Words is   : ' , token.text)
    print('POS is   : ' , token.pos_ ,'===', spacy.explain(token.pos_))
    print('Dep is   : ' , token.dep_ ,'===', spacy.explain(token.dep_))
    print('Tag is   : ' , token.tag_ ,'===', spacy.explain(token.tag_))
    print('-----------------------')
# Out:
# Words is   :  Khaled
# POS is   :  PROPN === proper noun
# Dep is   :  compound === compound
# Tag is   :  NNP === noun, proper singular
# -----------------------
# Words is   :  Ashraf
# POS is   :  PROPN === proper noun
# Dep is   :  nsubj === nominal subject
# Tag is   :  NNP === noun, proper singular
# -----------------------
# Words is   :  ,
# POS is   :  PUNCT === punctuation
# Dep is   :  punct === punctuation
# Tag is   :  , === punctuation mark, comma
# -----------------------
# Words is   :  an
# POS is   :  DET === determiner
# Dep is   :  det === determiner
# Tag is   :  DT === determiner
# -----------------------
# Words is   :  AI
# POS is   :  PROPN === proper noun
# Dep is   :  compound === compound
# Tag is   :  NNP === noun, proper singular
# -----------------------
# Words is   :  engineer
# POS is   :  NOUN === noun
# Dep is   :  appos === appositional modifier
# Tag is   :  NN === noun, singular or mass
# -----------------------
# Words is   :  from
# POS is   :  ADP === adposition
# Dep is   :  prep === prepositional modifier
# Tag is   :  IN === conjunction, subordinating or preposition
# -----------------------
# Words is   :  Egypt
# POS is   :  PROPN === proper noun
# Dep is   :  pobj === object of preposition
# Tag is   :  NNP === noun, proper singular
# -----------------------
# Words is   :  ,
# POS is   :  PUNCT === punctuation
# Dep is   :  punct === punctuation
# Tag is   :  , === punctuation mark, comma
# -----------------------
# Words is   :  has
# POS is   :  AUX === auxiliary
# Dep is   :  aux === auxiliary
# Tag is   :  VBZ === verb, 3rd person singular present
# -----------------------
# Words is   :  worked
# POS is   :  VERB === verb
# Dep is   :  ROOT === root
# Tag is   :  VBN === verb, past participle
# -----------------------
# Words is   :  on
# POS is   :  ADP === adposition
# Dep is   :  prep === prepositional modifier
# Tag is   :  IN === conjunction, subordinating or preposition
# -----------------------
# Words is   :  various
# POS is   :  ADJ === adjective
# Dep is   :  amod === adjectival modifier
# Tag is   :  JJ === adjective (English), other noun-modifier (Chinese)
# -----------------------
# Words is   :  projects
# POS is   :  NOUN === noun
# Dep is   :  pobj === object of preposition
# Tag is   :  NNS === noun, plural
# -----------------------
# Words is   :  in
# POS is   :  ADP === adposition
# Dep is   :  prep === prepositional modifier
# Tag is   :  IN === conjunction, subordinating or preposition
# -----------------------
# Words is   :  the
# POS is   :  DET === determiner
# Dep is   :  det === determiner
# Tag is   :  DT === determiner
# -----------------------
# Words is   :  field
# POS is   :  NOUN === noun
# Dep is   :  pobj === object of preposition
# Tag is   :  NN === noun, singular or mass
# -----------------------
# Words is   :  of
# POS is   :  ADP === adposition
# Dep is   :  prep === prepositional modifier
# Tag is   :  IN === conjunction, subordinating or preposition
# -----------------------
# Words is   :  machine
# POS is   :  NOUN === noun
# Dep is   :  compound === compound
# Tag is   :  NN === noun, singular or mass
# -----------------------
# Words is   :  learning
# POS is   :  NOUN === noun
# Dep is   :  pobj === object of preposition
# Tag is   :  NN === noun, singular or mass
# -----------------------
# Words is   :  .
# POS is   :  PUNCT === punctuation
# Dep is   :  punct === punctuation
# Tag is   :  . === punctuation mark, sentence closer
# -----------------------
# Words is   :
#
# POS is   :  SPACE === space
# Dep is   :  dep === unclassified dependent
# Tag is   :  _SP === whitespace
# -----------------------
# Words is   :  He
# POS is   :  PRON === pronoun
# Dep is   :  nsubj === nominal subject
# Tag is   :  PRP === pronoun, personal
# -----------------------
# Words is   :  completed
# POS is   :  VERB === verb
# Dep is   :  ROOT === root
# Tag is   :  VBD === verb, past tense
# -----------------------
# Words is   :  the
# POS is   :  DET === determiner
# Dep is   :  det === determiner
# Tag is   :  DT === determiner
# -----------------------
# Words is   :  '
# POS is   :  PUNCT === punctuation
# Dep is   :  punct === punctuation
# Tag is   :  `` === opening quotation mark
# -----------------------
# Words is   :  Deep
# POS is   :  PROPN === proper noun
# Dep is   :  compound === compound
# Tag is   :  NNP === noun, proper singular
# -----------------------
# Words is   :  Learning
# POS is   :  PROPN === proper noun
# Dep is   :  dobj === direct object
# Tag is   :  NNP === noun, proper singular
# -----------------------
# Words is   :  for
# POS is   :  ADP === adposition
# Dep is   :  prep === prepositional modifier
# Tag is   :  IN === conjunction, subordinating or preposition
# -----------------------
# Words is   :  Computer
# POS is   :  PROPN === proper noun
# Dep is   :  compound === compound
# Tag is   :  NNP === noun, proper singular
# -----------------------
# Words is   :  Vision
# POS is   :  PROPN === proper noun
# Dep is   :  poss === possession modifier
# Tag is   :  NNP === noun, proper singular
# -----------------------
# Words is   :  '
# POS is   :  PART === particle
# Dep is   :  case === case marking
# Tag is   :  POS === possessive ending
# -----------------------
# Words is   :  course
# POS is   :  NOUN === noun
# Dep is   :  pobj === object of preposition
# Tag is   :  NN === noun, singular or mass
# -----------------------
# Words is   :  on
# POS is   :  ADP === adposition
# Dep is   :  prep === prepositional modifier
# Tag is   :  IN === conjunction, subordinating or preposition
# -----------------------
# Words is   :  Udemy
# POS is   :  PROPN === proper noun
# Dep is   :  pobj === object of preposition
# Tag is   :  NNP === noun, proper singular
# -----------------------
# Words is   :  and
# POS is   :  CCONJ === coordinating conjunction
# Dep is   :  cc === coordinating conjunction
# Tag is   :  CC === conjunction, coordinating
# -----------------------
# Words is   :  has
# POS is   :  VERB === verb
# Dep is   :  conj === conjunct
# Tag is   :  VBZ === verb, 3rd person singular present
# -----------------------
# Words is   :  a
# POS is   :  DET === determiner
# Dep is   :  det === determiner
# Tag is   :  DT === determiner
# -----------------------
# Words is   :  deep
# POS is   :  ADJ === adjective
# Dep is   :  amod === adjectival modifier
# Tag is   :  JJ === adjective (English), other noun-modifier (Chinese)
# -----------------------
# Words is   :  passion
# POS is   :  NOUN === noun
# Dep is   :  dobj === direct object
# Tag is   :  NN === noun, singular or mass
# -----------------------
# Words is   :  for
# POS is   :  ADP === adposition
# Dep is   :  prep === prepositional modifier
# Tag is   :  IN === conjunction, subordinating or preposition
# -----------------------
# Words is   :  NLP
# POS is   :  PROPN === proper noun
# Dep is   :  pobj === object of preposition
# Tag is   :  NNP === noun, proper singular
# -----------------------
# Words is   :  and
# POS is   :  CCONJ === coordinating conjunction
# Dep is   :  cc === coordinating conjunction
# Tag is   :  CC === conjunction, coordinating
# -----------------------
# Words is   :  AI
# POS is   :  PROPN === proper noun
# Dep is   :  compound === compound
# Tag is   :  NNP === noun, proper singular
# -----------------------
# Words is   :  development
# POS is   :  NOUN === noun
# Dep is   :  conj === conjunct
# Tag is   :  NN === noun, singular or mass
# -----------------------
# Words is   :  .
# POS is   :  PUNCT === punctuation
# Dep is   :  punct === punctuation
# Tag is   :  . === punctuation mark, sentence closer
# -----------------------
# Words is   :
#
# POS is   :  SPACE === space
# Dep is   :  dep === unclassified dependent
# Tag is   :  _SP === whitespace
# -----------------------
# Words is   :  Khaled
# POS is   :  PROPN === proper noun
# Dep is   :  nsubjpass === nominal subject (passive)
# Tag is   :  NNP === noun, proper singular
# -----------------------
# Words is   :  is
# POS is   :  AUX === auxiliary
# Dep is   :  auxpass === auxiliary (passive)
# Tag is   :  VBZ === verb, 3rd person singular present
# -----------------------
# Words is   :  known
# POS is   :  VERB === verb
# Dep is   :  ROOT === root
# Tag is   :  VBN === verb, past participle
# -----------------------
# Words is   :  for
# POS is   :  ADP === adposition
# Dep is   :  prep === prepositional modifier
# Tag is   :  IN === conjunction, subordinating or preposition
# -----------------------
# Words is   :  his
# POS is   :  PRON === pronoun
# Dep is   :  poss === possession modifier
# Tag is   :  PRP$ === pronoun, possessive
# -----------------------
# Words is   :  expertise
# POS is   :  NOUN === noun
# Dep is   :  pobj === object of preposition
# Tag is   :  NN === noun, singular or mass
# -----------------------
# Words is   :  in
# POS is   :  ADP === adposition
# Dep is   :  prep === prepositional modifier
# Tag is   :  IN === conjunction, subordinating or preposition
# -----------------------
# Words is   :  computer
# POS is   :  NOUN === noun
# Dep is   :  compound === compound
# Tag is   :  NN === noun, singular or mass
# -----------------------
# Words is   :  vision
# POS is   :  NOUN === noun
# Dep is   :  pobj === object of preposition
# Tag is   :  NN === noun, singular or mass
# -----------------------
# Words is   :  and
# POS is   :  CCONJ === coordinating conjunction
# Dep is   :  cc === coordinating conjunction
# Tag is   :  CC === conjunction, coordinating
# -----------------------
# Words is   :  is
# POS is   :  AUX === auxiliary
# Dep is   :  aux === auxiliary
# Tag is   :  VBZ === verb, 3rd person singular present
# -----------------------
# Words is   :  actively
# POS is   :  ADV === adverb
# Dep is   :  advmod === adverbial modifier
# Tag is   :  RB === adverb
# -----------------------
# Words is   :  working
# POS is   :  VERB === verb
# Dep is   :  conj === conjunct
# Tag is   :  VBG === verb, gerund or present participle
# -----------------------
# Words is   :  on
# POS is   :  ADP === adposition
# Dep is   :  prep === prepositional modifier
# Tag is   :  IN === conjunction, subordinating or preposition
# -----------------------
# Words is   :  a
# POS is   :  DET === determiner
# Dep is   :  det === determiner
# Tag is   :  DT === determiner
# -----------------------
# Words is   :  Kaggle
# POS is   :  PROPN === proper noun
# Dep is   :  compound === compound
# Tag is   :  NNP === noun, proper singular
# -----------------------
# Words is   :  project
# POS is   :  NOUN === noun
# Dep is   :  pobj === object of preposition
# Tag is   :  NN === noun, singular or mass
# -----------------------
# Words is   :  to
# POS is   :  PART === particle
# Dep is   :  aux === auxiliary
# Tag is   :  TO === infinitival "to"
# -----------------------
# Words is   :  improve
# POS is   :  VERB === verb
# Dep is   :  advcl === adverbial clause modifier
# Tag is   :  VB === verb, base form
# -----------------------
# Words is   :  AI
# POS is   :  PROPN === proper noun
# Dep is   :  npadvmod === noun phrase as adverbial modifier
# Tag is   :  NNP === noun, proper singular
# -----------------------
# Words is   :  -
# POS is   :  PUNCT === punctuation
# Dep is   :  punct === punctuation
# Tag is   :  HYPH === punctuation mark, hyphen
# -----------------------
# Words is   :  based
# POS is   :  VERB === verb
# Dep is   :  amod === adjectival modifier
# Tag is   :  VBN === verb, past participle
# -----------------------
# Words is   :  systems
# POS is   :  NOUN === noun
# Dep is   :  dobj === direct object
# Tag is   :  NNS === noun, plural
# -----------------------
# Words is   :  .
# POS is   :  PUNCT === punctuation
# Dep is   :  punct === punctuation
# Tag is   :  . === punctuation mark, sentence closer
# -----------------------
# Words is   :
#
# POS is   :  SPACE === space
# Dep is   :  dep === unclassified dependent
# Tag is   :  _SP === whitespace
# -----------------------
# Words is   :  In
# POS is   :  ADP === adposition
# Dep is   :  prep === prepositional modifier
# Tag is   :  IN === conjunction, subordinating or preposition
# -----------------------
# Words is   :  his
# POS is   :  PRON === pronoun
# Dep is   :  poss === possession modifier
# Tag is   :  PRP$ === pronoun, possessive
# -----------------------
# Words is   :  spare
# POS is   :  ADJ === adjective
# Dep is   :  amod === adjectival modifier
# Tag is   :  JJ === adjective (English), other noun-modifier (Chinese)
# -----------------------
# Words is   :  time
# POS is   :  NOUN === noun
# Dep is   :  pobj === object of preposition
# Tag is   :  NN === noun, singular or mass
# -----------------------
# Words is   :  ,
# POS is   :  PUNCT === punctuation
# Dep is   :  punct === punctuation
# Tag is   :  , === punctuation mark, comma
# -----------------------
# Words is   :  he
# POS is   :  PRON === pronoun
# Dep is   :  nsubj === nominal subject
# Tag is   :  PRP === pronoun, personal
# -----------------------
# Words is   :  enjoys
# POS is   :  VERB === verb
# Dep is   :  ROOT === root
# Tag is   :  VBZ === verb, 3rd person singular present
# -----------------------
# Words is   :  exploring
# POS is   :  VERB === verb
# Dep is   :  xcomp === open clausal complement
# Tag is   :  VBG === verb, gerund or present participle
# -----------------------
# Words is   :  new
# POS is   :  ADJ === adjective
# Dep is   :  amod === adjectival modifier
# Tag is   :  JJ === adjective (English), other noun-modifier (Chinese)
# -----------------------
# Words is   :  AI
# POS is   :  PROPN === proper noun
# Dep is   :  compound === compound
# Tag is   :  NNP === noun, proper singular
# -----------------------
# Words is   :  technologies
# POS is   :  NOUN === noun
# Dep is   :  dobj === direct object
# Tag is   :  NNS === noun, plural
# -----------------------
# Words is   :  and
# POS is   :  CCONJ === coordinating conjunction
# Dep is   :  cc === coordinating conjunction
# Tag is   :  CC === conjunction, coordinating
# -----------------------
# Words is   :  sharing
# POS is   :  VERB === verb
# Dep is   :  conj === conjunct
# Tag is   :  VBG === verb, gerund or present participle
# -----------------------
# Words is   :  knowledge
# POS is   :  NOUN === noun
# Dep is   :  dobj === direct object
# Tag is   :  NN === noun, singular or mass
# -----------------------
# Words is   :  with
# POS is   :  ADP === adposition
# Dep is   :  prep === prepositional modifier
# Tag is   :  IN === conjunction, subordinating or preposition
# -----------------------
# Words is   :  others
# POS is   :  NOUN === noun
# Dep is   :  pobj === object of preposition
# Tag is   :  NNS === noun, plural
# -----------------------
# Words is   :  .
# POS is   :  PUNCT === punctuation
# Dep is   :  punct === punctuation
# Tag is   :  . === punctuation mark, sentence closer
# -----------------------

# %%
for token in doc1:
    print(f'{token.text:{10}} {token.pos_:{8}} {token.tag_:{6}} {spacy.explain(token.tag_)}')
# Out:
# Khaled     PROPN    NNP    noun, proper singular
# Ashraf     PROPN    NNP    noun, proper singular
# ,          PUNCT    ,      punctuation mark, comma
# an         DET      DT     determiner
# AI         PROPN    NNP    noun, proper singular
# engineer   NOUN     NN     noun, singular or mass
# from       ADP      IN     conjunction, subordinating or preposition
# Egypt      PROPN    NNP    noun, proper singular
# ,          PUNCT    ,      punctuation mark, comma
# has        AUX      VBZ    verb, 3rd person singular present
# worked     VERB     VBN    verb, past participle
# on         ADP      IN     conjunction, subordinating or preposition
# various    ADJ      JJ     adjective (English), other noun-modifier (Chinese)
# projects   NOUN     NNS    noun, plural
# in         ADP      IN     conjunction, subordinating or preposition
# the        DET      DT     determiner
# field      NOUN     NN     noun, singular or mass
# of         ADP      IN     conjunction, subordinating or preposition
# machine    NOUN     NN     noun, singular or mass
# learning   NOUN     NN     noun, singular or mass
# .          PUNCT    .      punctuation mark, sentence closer
#
#           SPACE    _SP    whitespace
# He         PRON     PRP    pronoun, personal
# completed  VERB     VBD    verb, past tense
# the        DET      DT     determiner
# '          PUNCT    ``     opening quotation mark
# Deep       PROPN    NNP    noun, proper singular
# Learning   PROPN    NNP    noun, proper singular
# for        ADP      IN     conjunction, subordinating or preposition
# Computer   PROPN    NNP    noun, proper singular
# Vision     PROPN    NNP    noun, proper singular
# '          PART     POS    possessive ending
# course     NOUN     NN     noun, singular or mass
# on         ADP      IN     conjunction, subordinating or preposition
# Udemy      PROPN    NNP    noun, proper singular
# and        CCONJ    CC     conjunction, coordinating
# has        VERB     VBZ    verb, 3rd person singular present
# a          DET      DT     determiner
# deep       ADJ      JJ     adjective (English), other noun-modifier (Chinese)
# passion    NOUN     NN     noun, singular or mass
# for        ADP      IN     conjunction, subordinating or preposition
# NLP        PROPN    NNP    noun, proper singular
# and        CCONJ    CC     conjunction, coordinating
# AI         PROPN    NNP    noun, proper singular
# development NOUN     NN     noun, singular or mass
# .          PUNCT    .      punctuation mark, sentence closer
#
#           SPACE    _SP    whitespace
# Khaled     PROPN    NNP    noun, proper singular
# is         AUX      VBZ    verb, 3rd person singular present
# known      VERB     VBN    verb, past participle
# for        ADP      IN     conjunction, subordinating or preposition
# his        PRON     PRP$   pronoun, possessive
# expertise  NOUN     NN     noun, singular or mass
# in         ADP      IN     conjunction, subordinating or preposition
# computer   NOUN     NN     noun, singular or mass
# vision     NOUN     NN     noun, singular or mass
# and        CCONJ    CC     conjunction, coordinating
# is         AUX      VBZ    verb, 3rd person singular present
# actively   ADV      RB     adverb
# working    VERB     VBG    verb, gerund or present participle
# on         ADP      IN     conjunction, subordinating or preposition
# a          DET      DT     determiner
# Kaggle     PROPN    NNP    noun, proper singular
# project    NOUN     NN     noun, singular or mass
# to         PART     TO     infinitival "to"
# improve    VERB     VB     verb, base form
# AI         PROPN    NNP    noun, proper singular
# -          PUNCT    HYPH   punctuation mark, hyphen
# based      VERB     VBN    verb, past participle
# systems    NOUN     NNS    noun, plural
# .          PUNCT    .      punctuation mark, sentence closer
#
#           SPACE    _SP    whitespace
# In         ADP      IN     conjunction, subordinating or preposition
# his        PRON     PRP$   pronoun, possessive
# spare      ADJ      JJ     adjective (English), other noun-modifier (Chinese)
# time       NOUN     NN     noun, singular or mass
# ,          PUNCT    ,      punctuation mark, comma
# he         PRON     PRP    pronoun, personal
# enjoys     VERB     VBZ    verb, 3rd person singular present
# exploring  VERB     VBG    verb, gerund or present participle
# new        ADJ      JJ     adjective (English), other noun-modifier (Chinese)
# AI         PROPN    NNP    noun, proper singular
# technologies NOUN     NNS    noun, plural
# and        CCONJ    CC     conjunction, coordinating
# sharing    VERB     VBG    verb, gerund or present participle
# knowledge  NOUN     NN     noun, singular or mass
# with       ADP      IN     conjunction, subordinating or preposition
# others     NOUN     NNS    noun, plural
# .          PUNCT    .      punctuation mark, sentence closer

# %%
doc = nlp(u'I read book now.')
r = doc[1]
print(f'{r.text:{10}} {r.pos_:{8}} {r.tag_:{6}} {spacy.explain(r.tag_)}')
# Out:
# read       VERB     VBP    verb, non-3rd person singular present

# %%
doc = nlp(u'I read a book on NLP.')
r = doc[1]
print(f'{r.text:{10}} {r.pos_:{8}} {r.tag_:{6}} {spacy.explain(r.tag_)}')
# Out:
# read       VERB     VBD    verb, past tense

# %%
POS_counts = doc1.count_by(spacy.attrs.POS)
for k,v in sorted(POS_counts.items()):
    print(f'{k}. {doc1.vocab[k].text:{5}}: {v}')
# Out:
# 84. ADJ  : 4
# 85. ADP  : 12
# 86. ADV  : 1
# 87. AUX  : 3
# 89. CCONJ: 4
# 90. DET  : 5
# 92. NOUN : 17
# 94. PART : 2
# 95. PRON : 4
# 96. PROPN: 15
# 97. PUNCT: 9
# 100. VERB : 10
# 103. SPACE: 3

# %%
TAG_counts = doc1.count_by(spacy.attrs.TAG)

for k,v in sorted(TAG_counts.items()):
    print(f'{k}. {doc1.vocab[k].text:{4}}: {v}')
# Out:
# 74. POS : 1
# 164681854541413346. RB  : 1
# 783433942507015291. NNS : 4
# 1292078113972184607. IN  : 12
# 1534113631682161808. VBG : 3
# 2593208677638477497. ,   : 3
# 3822385049556375858. VBN : 3
# 4062917326063685704. PRP$: 2
# 4969857429396651903. ``  : 1
# 5595707737748328492. TO  : 1
# 6893682062797376370. _SP : 3
# 8214596291009089021. HYPH: 1
# 10554686591937588953. JJ  : 4
# 12646065887601541794. .   : 4
# 13656873538139661788. PRP : 2
# 13927759927860985106. VBZ : 5
# 14200088355797579614. VB  : 1
# 15267657372422890137. DT  : 5
# 15308085513773655218. NN  : 13
# 15794550382381185553. NNP : 15
# 17109001835818727656. VBD : 1
# 17571114184892886314. CC  : 4

# %%
DEP_counts = doc1.count_by(spacy.attrs.DEP)

for k,v in sorted(DEP_counts.items()):
    print(f'{k}. {doc1.vocab[k].text:{4}}: {v}')
# Out:
# 399. advcl: 1
# 400. advmod: 1
# 402. amod: 5
# 403. appos: 1
# 405. aux : 3
# 406. auxpass: 1
# 407. cc  : 4
# 410. conj: 4
# 414. dep : 3
# 415. det : 5
# 416. dobj: 5
# 428. npadvmod: 1
# 429. nsubj: 3
# 430. nsubjpass: 1
# 439. pobj: 12
# 440. poss: 3
# 443. prep: 12
# 445. punct: 9
# 450. xcomp: 1
# 7037928807040764755. compound: 9
# 8110129090154140942. case: 1
# 8206900633647566924. ROOT: 4

# %%
import nltk
from nltk.corpus import state_union
from nltk.tokenize import PunktSentenceTokenizer

# %%
text = 'Moses supposes his toeses are roses but moses supposes erroneously'

for w , m in nltk.pos_tag(nltk.word_tokenize(text)):
    print(f'word : ({w}), type : ({m}) , means :  ({spacy.explain(m)})')
# Out:
# word : (Moses), type : (NNS) , means :  (noun, plural)
# word : (supposes), type : (VBZ) , means :  (verb, 3rd person singular present)
# word : (his), type : (PRP$) , means :  (pronoun, possessive)
# word : (toeses), type : (NNS) , means :  (noun, plural)
# word : (are), type : (VBP) , means :  (verb, non-3rd person singular present)
# word : (roses), type : (NNS) , means :  (noun, plural)
# word : (but), type : (CC) , means :  (conjunction, coordinating)
# word : (moses), type : (VBZ) , means :  (verb, 3rd person singular present)
# word : (supposes), type : (NNS) , means :  (noun, plural)
# word : (erroneously), type : (RB) , means :  (adverb)

# %%
text = '''
Thomas Gradgrind, sir.  A man of realities.  A man of facts and calculations.  A man who proceeds upon the principle that
two and two are four, and nothing over, and who is not to be talked into allowing for anything over.  Thomas Gradgrind, 
sir—peremptorily Thomas—Thomas Gradgrind.  With a rule and a pair of scales, and the multiplication table always in his pocket, 
sir, ready to weigh and measure any parcel of human nature, and tell you exactly what it comes to.  It is a mere question of
figures, a case of simple arithmetic.  You might hope to get some other nonsensical belief into the head of George Gradgrind, or Augustus Gradgrind, or John Gradgrind, or Joseph Gradgrind (all supposititious, non-existent persons), but into the head of Thomas Gradgrind—no, sir!

In such terms Mr. Gradgrind always mentally introduced himself, whether to his private circle of acquaintance, or to the public in general.  In such terms, no doubt, substituting the words ‘boys and girls,’ for ‘sir,’ Thomas Gradgrind now presented Thomas Gradgrind to the little pitchers before him, who were to be filled so full of facts.
'''

# %%
custom_sent_tokenizer = PunktSentenceTokenizer(text)
tokenized = custom_sent_tokenizer.tokenize(text)
tokenized[:10]
# Out:
# ['\nThomas Gradgrind, sir.',
#  'A man of realities.',
#  'A man of facts and calculations.',
#  'A man who proceeds upon the principle that\ntwo and two are four, and nothing over, and who is not to be talked into allowing for anything over.',
#  'Thomas Gradgrind, \nsir—peremptorily Thomas—Thomas Gradgrind.',
#  'With a rule and a pair of scales, and the multiplication table always in his pocket, \nsir, ready to weigh and measure any parcel of human nature, and tell you exactly what it comes to.',
#  'It is a mere question of\nfigures, a case of simple arithmetic.',
#  'You might hope to get some other nonsensical belief into the head of George Gradgrind, or Augustus Gradgrind, or John Gradgrind, or Joseph Gradgrind (all supposititious, non-existent persons), but into the head of Thomas Gradgrind—no, sir!',
#  'In such terms Mr. Gradgrind always mentally introduced himself, whether to his private circle of acquaintance, or to the public in general.',
#  'In such terms, no doubt, substituting the words ‘boys and girls,’ for ‘sir,’ Thomas Gradgrind now presented Thomas Gradgrind to the little pitchers before him, who were to be filled so full of facts.']

# %%
import re           
train_text = state_union.raw("2005-GWBush.txt")
sample_text = state_union.raw("2006-GWBush.txt")

# %%
train_text
# Out:
# 'PRESIDENT GEORGE W. BUSH\'S ADDRESS BEFORE A JOINT SESSION OF THE CONGRESS ON THE STATE OF THE UNION\n \nFebruary 2, 2005\n\n\n9:10 P.M. EST \n\nTHE PRESIDENT: Mr. Speaker, Vice President Cheney, members of Congress, fellow citizens: \n\nAs a new Congress gathers, all of us in the elected branches of government share a great privilege: We\'ve been placed in office by the votes of the people we serve. And tonight that is a privilege we share with newly-elected leaders of Afghanistan, the Palestinian Territories, Ukraine, and a free and sovereign Iraq. (Applause.) \n\nTwo weeks ago, I stood on the steps of this Capitol and renewed the commitment of our nation to the guiding ideal of liberty for all. This evening I will set forth policies to advance that ideal at home and around the world. \n\nTonight, with a healthy, growing economy, with more Americans going back to work, with our nation an active force for good in the world -- the state of our union is confident and strong. (Applause.) \n\nOur generation has been blessed -- by the expansion of opportunity, by advances in medicine, by the security purchased by our parents\' sacrifice. Now, as we see a little gray in the mirror -- or a lot of gray -- (laughter) -- and we watch our children moving into adulthood, we ask the question: What will be the state of their union? Members of Congress, the choices we make together will answer that question. Over the next several months, on issue after issue, let us do what Americans have always done, and build a better world for our children and our grandchildren. (Applause.) \n\nFirst, we must be good stewards of this economy, and renew the great institutions on which millions of our fellow citizens rely. America\'s economy is the fastest growing of any major industrialized nation. In the past four years, we provided tax relief to every person who pays income taxes, overcome a recession, opened up new markets abroad, prosecuted corporate criminals, raised homeownership to its highest level in history, and in the last year alone, the United States has added 2.3 million new jobs. (Applause.) When action was needed, the Congress delivered -- and the nation is grateful. \n\nNow we must add to these achievements. By making our economy more flexible, more innovative, and more competitive, we will keep America the economic leader of the world. (Applause.) \n\nAmerica\'s prosperity requires restraining the spending appetite of the federal government. I welcome the bipartisan enthusiasm for spending discipline. I will send you a budget that holds the growth of discretionary spending below inflation, makes tax relief permanent, and stays on track to cut the deficit in half by 2009. (Applause.) My budget substantially reduces or eliminates more than 150 government programs that are not getting results, or duplicate current efforts, or do not fulfill essential priorities. The principle here is clear: Taxpayer dollars must be spent wisely, or not at all. (Applause.) \n\nTo make our economy stronger and more dynamic, we must prepare a rising generation to fill the jobs of the 21st century. Under the No Child Left Behind Act, standards are higher, test scores are on the rise, and we\'re closing the achievement gap for minority students. Now we must demand better results from our high schools, so every high school diploma is a ticket to success. We will help an additional 200,000 workers to get training for a better career, by reforming our job training system and strengthening America\'s community colleges. And we\'ll make it easier for Americans to afford a college education, by increasing the size of Pell Grants. (Applause.) \n\nTo make our economy stronger and more competitive, America must reward, not punish, the efforts and dreams of entrepreneurs. Small business is the path of advancement, especially for women and minorities, so we must free small businesses from needless regulation and protect honest job-creators from junk lawsuits. (Applause.)  ...

# %%
custom_sent_tokenizer = PunktSentenceTokenizer(train_text)
tokenized = custom_sent_tokenizer.tokenize(sample_text)
tokenized[:5]
# Out:
# ["PRESIDENT GEORGE W. BUSH'S ADDRESS BEFORE A JOINT SESSION OF THE CONGRESS ON THE STATE OF THE UNION\n \nJanuary 31, 2006\n\nTHE PRESIDENT: Thank you all.",
#  'Mr. Speaker, Vice President Cheney, members of Congress, members of the Supreme Court and diplomatic corps, distinguished guests, and fellow citizens: Today our nation lost a beloved, graceful, courageous woman who called America to its founding ideals and carried on a noble dream.',
#  'Tonight we are comforted by the hope of a glad reunion with the husband who was taken so long ago, and we are grateful for the good life of Coretta Scott King.',
#  '(Applause.)',
#  'President George W. Bush reacts to applause during his State of the Union Address at the Capitol, Tuesday, Jan.']

# %%
doc1 = nlp('''ضمت مؤلفات الخوارزمي كتاب الجمع والتفريق
في الحساب الهندي، وكتاب رسم الربع المعمور، وكتاب تقويم البلدان، وكتاب العمل بالأسطرلاب، 
وكتاب "صورة الأرض " الذي اعتمد فيه على كتاب المجسطي لبطليموس مع إضافات وشروح
وتعليقات، وأعاد كتابة كتاب الفلك الهندي المعروف باسم "السند هند الكبير" الذي ترجم إلى اللغة
العربية زمن الخليفة المنصور فأعاد الخوارزمي كتابته وأضاف إليه وسمي كتابه "السند هند الصغير".

وقد عرض في كتاب المختصر في حساب الجبر والمقابلة أول حل منهجي
للمعادلات الخطية والمعادلات التربيعية مستعملا في ذلك الطريقة المعروفة باسم إكمال المربع. ويعتبر مؤسس علم الجبر،
(اللقب الذي يتقاسمه مع ديوفانتوس) في القرن الثاني عشر، ولقد قدمت ترجمات اللاتينية عن حسابه على الأرقام الهندية، 
النظام العشري إلى العالم الغربي. نقح الخوارزمي كتاب الجغرافيا لكلاوديوس بطليموس وكتب في علم الفلك والتنجيم.
''')


for token in doc1:
    print('Words is   : ' , token.text)
    print('POS is   : ' , token.pos ,'===',token.pos_  , '===', spacy.explain(token.pos_))
    print('Dep is   : ' , token.dep , '===',token.dep_, '===', spacy.explain(token.dep_))
    print('Tag is   : ' , token.tag , '===',token.tag_, '===', spacy.explain(token.tag_))
    print('-----------------------')
# Out:
# Words is   :  ضمت
# POS is   :  92 === NOUN === noun
# Dep is   :  429 === nsubj === nominal subject
# Tag is   :  15308085513773655218 === NN === noun, singular or mass
# -----------------------
# Words is   :  مؤلفات
# POS is   :  96 === PROPN === proper noun
# Dep is   :  428 === npadvmod === noun phrase as adverbial modifier
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  الخوارزمي
# POS is   :  100 === VERB === verb
# Dep is   :  8206900633647566924 === ROOT === root
# Tag is   :  17109001835818727656 === VBD === verb, past tense
# -----------------------
# Words is   :  كتاب
# POS is   :  96 === PROPN === proper noun
# Dep is   :  416 === dobj === direct object
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  الجمع
# POS is   :  96 === PROPN === proper noun
# Dep is   :  7037928807040764755 === compound === compound
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  والتفريق
# POS is   :  96 === PROPN === proper noun
# Dep is   :  7037928807040764755 === compound === compound
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :
#
# POS is   :  103 === SPACE === space
# Dep is   :  414 === dep === unclassified dependent
# Tag is   :  6893682062797376370 === _SP === whitespace
# -----------------------
# Words is   :  في
# POS is   :  96 === PROPN === proper noun
# Dep is   :  429 === nsubj === nominal subject
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  الحساب
# POS is   :  96 === PROPN === proper noun
# Dep is   :  7037928807040764755 === compound === compound
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  الهندي
# POS is   :  96 === PROPN === proper noun
# Dep is   :  7037928807040764755 === compound === compound
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  ،
# POS is   :  96 === PROPN === proper noun
# Dep is   :  7037928807040764755 === compound === compound
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  وكتاب
# POS is   :  96 === PROPN === proper noun
# Dep is   :  7037928807040764755 === compound === compound
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  رسم
# POS is   :  96 === PROPN === proper noun
# Dep is   :  7037928807040764755 === compound === compound
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  الربع
# POS is   :  96 === PROPN === proper noun
# Dep is   :  408 === ccomp === clausal complement
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  المعمور
# POS is   :  96 === PROPN === proper noun
# Dep is   :  7037928807040764755 === compound === compound
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  ،
# POS is   :  96 === PROPN === proper noun
# Dep is   :  7037928807040764755 === compound === compound
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  وكتاب
# POS is   :  96 === PROPN === proper noun
# Dep is   :  7037928807040764755 === compound === compound
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  تقويم
# POS is   :  96 === PROPN === proper noun
# Dep is   :  7037928807040764755 === compound === compound
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  البلدان
# POS is   :  96 === PROPN === proper noun
# Dep is   :  7037928807040764755 === compound === compound
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  ،
# POS is   :  96 === PROPN === proper noun
# Dep is   :  7037928807040764755 === compound === compound
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  وكتاب
# POS is   :  96 === PROPN === proper noun
# Dep is   :  7037928807040764755 === compound === compound
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  العمل
# POS is   :  96 === PROPN === proper noun
# Dep is   :  416 === dobj === direct object
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  بالأسطرلاب
# POS is   :  96 === PROPN === proper noun
# Dep is   :  7037928807040764755 === compound === compound
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  ،
# POS is   :  96 === PROPN === proper noun
# Dep is   :  7037928807040764755 === compound === compound
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :
#
# POS is   :  103 === SPACE === space
# Dep is   :  414 === dep === unclassified dependent
# Tag is   :  6893682062797376370 === _SP === whitespace
# -----------------------
# Words is   :  وكتاب
# POS is   :  96 === PROPN === proper noun
# Dep is   :  416 === dobj === direct object
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  "
# POS is   :  97 === PUNCT === punctuation
# Dep is   :  445 === punct === punctuation
# Tag is   :  4969857429396651903 === `` === opening quotation mark
# -----------------------
# Words is   :  صورة
# POS is   :  96 === PROPN === proper noun
# Dep is   :  426 === nmod === modifier of nominal
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  الأرض
# POS is   :  96 === PROPN === proper noun
# Dep is   :  426 === nmod === modifier of nominal
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  "
# POS is   :  97 === PUNCT === punctuation
# Dep is   :  445 === punct === punctuation
# Tag is   :  14143520107006108953 === '' === closing quotation mark
# -----------------------
# Words is   :  الذي
# POS is   :  96 === PROPN === proper noun
# Dep is   :  7037928807040764755 === compound === compound
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  اعتمد
# POS is   :  96 === PROPN === proper noun
# Dep is   :  7037928807040764755 === compound === compound
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  فيه
# POS is   :  96 === PROPN === proper noun
# Dep is   :  7037928807040764755 === compound === compound
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  على
# POS is   :  96 === PROPN === proper noun
# Dep is   :  7037928807040764755 === compound === compound
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  كتاب
# POS is   :  96 === PROPN === proper noun
# Dep is   :  429 === nsubj === nominal subject
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  المجسطي
# POS is   :  86 === ADV === adverb
# Dep is   :  400 === advmod === adverbial modifier
# Tag is   :  164681854541413346 === RB === adverb
# -----------------------
# Words is   :  لبطليموس
# POS is   :  100 === VERB === verb
# Dep is   :  7037928807040764755 === compound === compound
# Tag is   :  9188597074677201817 === VBP === verb, non-3rd person singular present
# -----------------------
# Words is   :  مع
# POS is   :  96 === PROPN === proper noun
# Dep is   :  7037928807040764755 === compound === compound
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  إضافات
# POS is   :  96 === PROPN === proper noun
# Dep is   :  7037928807040764755 === compound === compound
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  وشروح
# POS is   :  92 === NOUN === noun
# Dep is   :  7037928807040764755 === compound === compound
# Tag is   :  15308085513773655218 === NN === noun, singular or mass
# -----------------------
# Words is   :
#
# POS is   :  103 === SPACE === space
# Dep is   :  414 === dep === unclassified dependent
# Tag is   :  6893682062797376370 === _SP === whitespace
# -----------------------
# Words is   :  وتعليقات
# POS is   :  96 === PROPN === proper noun
# Dep is   :  7037928807040764755 === compound === compound
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  ،
# POS is   :  96 === PROPN === proper noun
# Dep is   :  7037928807040764755 === compound === compound
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  وأعاد
# POS is   :  96 === PROPN === proper noun
# Dep is   :  7037928807040764755 === compound === compound
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  كتابة
# POS is   :  96 === PROPN === proper noun
# Dep is   :  7037928807040764755 === compound === compound
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  كتاب
# POS is   :  96 === PROPN === proper noun
# Dep is   :  7037928807040764755 === compound === compound
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  الفلك
# POS is   :  96 === PROPN === proper noun
# Dep is   :  426 === nmod === modifier of nominal
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  الهندي
# POS is   :  92 === NOUN === noun
# Dep is   :  7037928807040764755 === compound === compound
# Tag is   :  15308085513773655218 === NN === noun, singular or mass
# -----------------------
# Words is   :  المعروف
# POS is   :  92 === NOUN === noun
# Dep is   :  7037928807040764755 === compound === compound
# Tag is   :  15308085513773655218 === NN === noun, singular or mass
# -----------------------
# Words is   :  باسم
# POS is   :  92 === NOUN === noun
# Dep is   :  429 === nsubj === nominal subject
# Tag is   :  15308085513773655218 === NN === noun, singular or mass
# -----------------------
# Words is   :  "
# POS is   :  97 === PUNCT === punctuation
# Dep is   :  445 === punct === punctuation
# Tag is   :  4969857429396651903 === `` === opening quotation mark
# -----------------------
# Words is   :  السند
# POS is   :  100 === VERB === verb
# Dep is   :  408 === ccomp === clausal complement
# Tag is   :  13927759927860985106 === VBZ === verb, 3rd person singular present
# -----------------------
# Words is   :  هند
# POS is   :  96 === PROPN === proper noun
# Dep is   :  7037928807040764755 === compound === compound
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  الكبير
# POS is   :  96 === PROPN === proper noun
# Dep is   :  426 === nmod === modifier of nominal
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  "
# POS is   :  97 === PUNCT === punctuation
# Dep is   :  445 === punct === punctuation
# Tag is   :  14143520107006108953 === '' === closing quotation mark
# -----------------------
# Words is   :  الذي
# POS is   :  96 === PROPN === proper noun
# Dep is   :  426 === nmod === modifier of nominal
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  ترجم
# POS is   :  92 === NOUN === noun
# Dep is   :  7037928807040764755 === compound === compound
# Tag is   :  15308085513773655218 === NN === noun, singular or mass
# -----------------------
# Words is   :  إلى
# POS is   :  96 === PROPN === proper noun
# Dep is   :  7037928807040764755 === compound === compound
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  اللغة
# POS is   :  96 === PROPN === proper noun
# Dep is   :  416 === dobj === direct object
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :
#
# POS is   :  103 === SPACE === space
# Dep is   :  414 === dep === unclassified dependent
# Tag is   :  6893682062797376370 === _SP === whitespace
# -----------------------
# Words is   :  العربية
# POS is   :  96 === PROPN === proper noun
# Dep is   :  7037928807040764755 === compound === compound
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  زمن
# POS is   :  96 === PROPN === proper noun
# Dep is   :  7037928807040764755 === compound === compound
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  الخليفة
# POS is   :  96 === PROPN === proper noun
# Dep is   :  7037928807040764755 === compound === compound
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  المنصور
# POS is   :  96 === PROPN === proper noun
# Dep is   :  7037928807040764755 === compound === compound
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  فأعاد
# POS is   :  96 === PROPN === proper noun
# Dep is   :  7037928807040764755 === compound === compound
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  الخوارزمي
# POS is   :  96 === PROPN === proper noun
# Dep is   :  7037928807040764755 === compound === compound
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  كتابته
# POS is   :  96 === PROPN === proper noun
# Dep is   :  429 === nsubj === nominal subject
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  وأضاف
# POS is   :  96 === PROPN === proper noun
# Dep is   :  8206900633647566924 === ROOT === root
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  إليه
# POS is   :  96 === PROPN === proper noun
# Dep is   :  443 === prep === prepositional modifier
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  وسمي
# POS is   :  96 === PROPN === proper noun
# Dep is   :  7037928807040764755 === compound === compound
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  كتابه
# POS is   :  96 === PROPN === proper noun
# Dep is   :  429 === nsubj === nominal subject
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  "
# POS is   :  97 === PUNCT === punctuation
# Dep is   :  445 === punct === punctuation
# Tag is   :  4969857429396651903 === `` === opening quotation mark
# -----------------------
# Words is   :  السند
# POS is   :  100 === VERB === verb
# Dep is   :  410 === conj === conjunct
# Tag is   :  13927759927860985106 === VBZ === verb, 3rd person singular present
# -----------------------
# Words is   :  هند
# POS is   :  96 === PROPN === proper noun
# Dep is   :  7037928807040764755 === compound === compound
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  الصغير
# POS is   :  96 === PROPN === proper noun
# Dep is   :  416 === dobj === direct object
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  "
# POS is   :  97 === PUNCT === punctuation
# Dep is   :  445 === punct === punctuation
# Tag is   :  14143520107006108953 === '' === closing quotation mark
# -----------------------
# Words is   :  .
# POS is   :  97 === PUNCT === punctuation
# Dep is   :  445 === punct === punctuation
# Tag is   :  12646065887601541794 === . === punctuation mark, sentence closer
# -----------------------
# Words is   :
#
#
# POS is   :  103 === SPACE === space
# Dep is   :  414 === dep === unclassified dependent
# Tag is   :  6893682062797376370 === _SP === whitespace
# -----------------------
# Words is   :  وقد
# POS is   :  92 === NOUN === noun
# Dep is   :  7037928807040764755 === compound === compound
# Tag is   :  15308085513773655218 === NN === noun, singular or mass
# -----------------------
# Words is   :  عرض
# POS is   :  92 === NOUN === noun
# Dep is   :  7037928807040764755 === compound === compound
# Tag is   :  15308085513773655218 === NN === noun, singular or mass
# -----------------------
# Words is   :  في
# POS is   :  91 === INTJ === interjection
# Dep is   :  402 === amod === adjectival modifier
# Tag is   :  3252815442139690129 === UH === interjection
# -----------------------
# Words is   :  كتاب
# POS is   :  96 === PROPN === proper noun
# Dep is   :  7037928807040764755 === compound === compound
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  المختصر
# POS is   :  92 === NOUN === noun
# Dep is   :  8206900633647566924 === ROOT === root
# Tag is   :  15308085513773655218 === NN === noun, singular or mass
# -----------------------
# Words is   :  في
# POS is   :  96 === PROPN === proper noun
# Dep is   :  7037928807040764755 === compound === compound
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  حساب
# POS is   :  96 === PROPN === proper noun
# Dep is   :  7037928807040764755 === compound === compound
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  الجبر
# POS is   :  96 === PROPN === proper noun
# Dep is   :  7037928807040764755 === compound === compound
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  والمقابلة
# POS is   :  96 === PROPN === proper noun
# Dep is   :  7037928807040764755 === compound === compound
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  أول
# POS is   :  96 === PROPN === proper noun
# Dep is   :  7037928807040764755 === compound === compound
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  حل
# POS is   :  96 === PROPN === proper noun
# Dep is   :  7037928807040764755 === compound === compound
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  منهجي
# POS is   :  96 === PROPN === proper noun
# Dep is   :  7037928807040764755 === compound === compound
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :
#
# POS is   :  103 === SPACE === space
# Dep is   :  414 === dep === unclassified dependent
# Tag is   :  6893682062797376370 === _SP === whitespace
# -----------------------
# Words is   :  للمعادلات
# POS is   :  96 === PROPN === proper noun
# Dep is   :  402 === amod === adjectival modifier
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  الخطية
# POS is   :  92 === NOUN === noun
# Dep is   :  7037928807040764755 === compound === compound
# Tag is   :  15308085513773655218 === NN === noun, singular or mass
# -----------------------
# Words is   :  والمعادلات
# POS is   :  96 === PROPN === proper noun
# Dep is   :  403 === appos === appositional modifier
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  التربيعية
# POS is   :  96 === PROPN === proper noun
# Dep is   :  7037928807040764755 === compound === compound
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  مستعملا
# POS is   :  96 === PROPN === proper noun
# Dep is   :  7037928807040764755 === compound === compound
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  في
# POS is   :  96 === PROPN === proper noun
# Dep is   :  8206900633647566924 === ROOT === root
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  ذلك
# POS is   :  96 === PROPN === proper noun
# Dep is   :  429 === nsubj === nominal subject
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  الطريقة
# POS is   :  100 === VERB === verb
# Dep is   :  8206900633647566924 === ROOT === root
# Tag is   :  13927759927860985106 === VBZ === verb, 3rd person singular present
# -----------------------
# Words is   :  المعروفة
# POS is   :  96 === PROPN === proper noun
# Dep is   :  7037928807040764755 === compound === compound
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  باسم
# POS is   :  96 === PROPN === proper noun
# Dep is   :  7037928807040764755 === compound === compound
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  إكمال
# POS is   :  96 === PROPN === proper noun
# Dep is   :  7037928807040764755 === compound === compound
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  المربع
# POS is   :  92 === NOUN === noun
# Dep is   :  416 === dobj === direct object
# Tag is   :  783433942507015291 === NNS === noun, plural
# -----------------------
# Words is   :  .
# POS is   :  97 === PUNCT === punctuation
# Dep is   :  445 === punct === punctuation
# Tag is   :  12646065887601541794 === . === punctuation mark, sentence closer
# -----------------------
# Words is   :  ويعتبر
# POS is   :  100 === VERB === verb
# Dep is   :  8206900633647566924 === ROOT === root
# Tag is   :  14200088355797579614 === VB === verb, base form
# -----------------------
# Words is   :  مؤسس
# POS is   :  96 === PROPN === proper noun
# Dep is   :  7037928807040764755 === compound === compound
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  علم
# POS is   :  96 === PROPN === proper noun
# Dep is   :  7037928807040764755 === compound === compound
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  الجبر
# POS is   :  96 === PROPN === proper noun
# Dep is   :  416 === dobj === direct object
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  ،
# POS is   :  96 === PROPN === proper noun
# Dep is   :  403 === appos === appositional modifier
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :
#
# POS is   :  103 === SPACE === space
# Dep is   :  414 === dep === unclassified dependent
# Tag is   :  6893682062797376370 === _SP === whitespace
# -----------------------
# Words is   :  (
# POS is   :  97 === PUNCT === punctuation
# Dep is   :  445 === punct === punctuation
# Tag is   :  17111077179131903759 === -LRB- === left round bracket
# -----------------------
# Words is   :  اللقب
# POS is   :  96 === PROPN === proper noun
# Dep is   :  7037928807040764755 === compound === compound
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  الذي
# POS is   :  96 === PROPN === proper noun
# Dep is   :  7037928807040764755 === compound === compound
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  يتقاسمه
# POS is   :  96 === PROPN === proper noun
# Dep is   :  7037928807040764755 === compound === compound
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  مع
# POS is   :  96 === PROPN === proper noun
# Dep is   :  7037928807040764755 === compound === compound
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  ديوفانتوس
# POS is   :  96 === PROPN === proper noun
# Dep is   :  416 === dobj === direct object
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  )
# POS is   :  97 === PUNCT === punctuation
# Dep is   :  445 === punct === punctuation
# Tag is   :  2465883113906300949 === -RRB- === right round bracket
# -----------------------
# Words is   :  في
# POS is   :  89 === CCONJ === coordinating conjunction
# Dep is   :  414 === dep === unclassified dependent
# Tag is   :  17571114184892886314 === CC === conjunction, coordinating
# -----------------------
# Words is   :  القرن
# POS is   :  96 === PROPN === proper noun
# Dep is   :  414 === dep === unclassified dependent
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  الثاني
# POS is   :  96 === PROPN === proper noun
# Dep is   :  7037928807040764755 === compound === compound
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  عشر
# POS is   :  96 === PROPN === proper noun
# Dep is   :  403 === appos === appositional modifier
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  ،
# POS is   :  96 === PROPN === proper noun
# Dep is   :  7037928807040764755 === compound === compound
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  ولقد
# POS is   :  96 === PROPN === proper noun
# Dep is   :  7037928807040764755 === compound === compound
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  قدمت
# POS is   :  96 === PROPN === proper noun
# Dep is   :  7037928807040764755 === compound === compound
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  ترجمات
# POS is   :  96 === PROPN === proper noun
# Dep is   :  7037928807040764755 === compound === compound
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  اللاتينية
# POS is   :  96 === PROPN === proper noun
# Dep is   :  7037928807040764755 === compound === compound
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  عن
# POS is   :  96 === PROPN === proper noun
# Dep is   :  7037928807040764755 === compound === compound
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  حسابه
# POS is   :  96 === PROPN === proper noun
# Dep is   :  7037928807040764755 === compound === compound
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  على
# POS is   :  96 === PROPN === proper noun
# Dep is   :  429 === nsubj === nominal subject
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  الأرقام
# POS is   :  96 === PROPN === proper noun
# Dep is   :  400 === advmod === adverbial modifier
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  الهندية
# POS is   :  96 === PROPN === proper noun
# Dep is   :  7037928807040764755 === compound === compound
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  ،
# POS is   :  96 === PROPN === proper noun
# Dep is   :  7037928807040764755 === compound === compound
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :
#
# POS is   :  103 === SPACE === space
# Dep is   :  414 === dep === unclassified dependent
# Tag is   :  6893682062797376370 === _SP === whitespace
# -----------------------
# Words is   :  النظام
# POS is   :  96 === PROPN === proper noun
# Dep is   :  429 === nsubj === nominal subject
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  العشري
# POS is   :  100 === VERB === verb
# Dep is   :  8206900633647566924 === ROOT === root
# Tag is   :  14200088355797579614 === VB === verb, base form
# -----------------------
# Words is   :  إلى
# POS is   :  96 === PROPN === proper noun
# Dep is   :  7037928807040764755 === compound === compound
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  العالم
# POS is   :  92 === NOUN === noun
# Dep is   :  416 === dobj === direct object
# Tag is   :  783433942507015291 === NNS === noun, plural
# -----------------------
# Words is   :  الغربي
# POS is   :  84 === ADJ === adjective
# Dep is   :  400 === advmod === adverbial modifier
# Tag is   :  10554686591937588953 === JJ === adjective (English), other noun-modifier (Chinese)
# -----------------------
# Words is   :  .
# POS is   :  97 === PUNCT === punctuation
# Dep is   :  445 === punct === punctuation
# Tag is   :  12646065887601541794 === . === punctuation mark, sentence closer
# -----------------------
# Words is   :  نقح
# POS is   :  96 === PROPN === proper noun
# Dep is   :  429 === nsubj === nominal subject
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  الخوارزمي
# POS is   :  96 === PROPN === proper noun
# Dep is   :  7037928807040764755 === compound === compound
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  كتاب
# POS is   :  96 === PROPN === proper noun
# Dep is   :  7037928807040764755 === compound === compound
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  الجغرافيا
# POS is   :  96 === PROPN === proper noun
# Dep is   :  7037928807040764755 === compound === compound
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  لكلاوديوس
# POS is   :  96 === PROPN === proper noun
# Dep is   :  7037928807040764755 === compound === compound
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  بطليموس
# POS is   :  92 === NOUN === noun
# Dep is   :  416 === dobj === direct object
# Tag is   :  15308085513773655218 === NN === noun, singular or mass
# -----------------------
# Words is   :  وكتب
# POS is   :  96 === PROPN === proper noun
# Dep is   :  7037928807040764755 === compound === compound
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  في
# POS is   :  96 === PROPN === proper noun
# Dep is   :  415 === det === determiner
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  علم
# POS is   :  96 === PROPN === proper noun
# Dep is   :  7037928807040764755 === compound === compound
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  الفلك
# POS is   :  96 === PROPN === proper noun
# Dep is   :  7037928807040764755 === compound === compound
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  والتنجيم
# POS is   :  96 === PROPN === proper noun
# Dep is   :  8206900633647566924 === ROOT === root
# Tag is   :  15794550382381185553 === NNP === noun, proper singular
# -----------------------
# Words is   :  .
# POS is   :  97 === PUNCT === punctuation
# Dep is   :  445 === punct === punctuation
# Tag is   :  12646065887601541794 === . === punctuation mark, sentence closer
# -----------------------
# Words is   :
#
# POS is   :  103 === SPACE === space
# Dep is   :  414 === dep === unclassified dependent
# Tag is   :  6893682062797376370 === _SP === whitespace
# -----------------------

# %%
for token in doc1:
    print(f'{token.text:{10}} {token.pos_:{8}} {token.tag_:{6}} {spacy.explain(token.tag_)}')
# Out:
# ضمت        NOUN     NN     noun, singular or mass
# مؤلفات     PROPN    NNP    noun, proper singular
# الخوارزمي  VERB     VBD    verb, past tense
# كتاب       PROPN    NNP    noun, proper singular
# الجمع      PROPN    NNP    noun, proper singular
# والتفريق   PROPN    NNP    noun, proper singular
#
#           SPACE    _SP    whitespace
# في         PROPN    NNP    noun, proper singular
# الحساب     PROPN    NNP    noun, proper singular
# الهندي     PROPN    NNP    noun, proper singular
# ،          PROPN    NNP    noun, proper singular
# وكتاب      PROPN    NNP    noun, proper singular
# رسم        PROPN    NNP    noun, proper singular
# الربع      PROPN    NNP    noun, proper singular
# المعمور    PROPN    NNP    noun, proper singular
# ،          PROPN    NNP    noun, proper singular
# وكتاب      PROPN    NNP    noun, proper singular
# تقويم      PROPN    NNP    noun, proper singular
# البلدان    PROPN    NNP    noun, proper singular
# ،          PROPN    NNP    noun, proper singular
# وكتاب      PROPN    NNP    noun, proper singular
# العمل      PROPN    NNP    noun, proper singular
# بالأسطرلاب PROPN    NNP    noun, proper singular
# ،          PROPN    NNP    noun, proper singular
#
#           SPACE    _SP    whitespace
# وكتاب      PROPN    NNP    noun, proper singular
# "          PUNCT    ``     opening quotation mark
# صورة       PROPN    NNP    noun, proper singular
# الأرض      PROPN    NNP    noun, proper singular
# "          PUNCT    ''     closing quotation mark
# الذي       PROPN    NNP    noun, proper singular
# اعتمد      PROPN    NNP    noun, proper singular
# فيه        PROPN    NNP    noun, proper singular
# على        PROPN    NNP    noun, proper singular
# كتاب       PROPN    NNP    noun, proper singular
# المجسطي    ADV      RB     adverb
# لبطليموس   VERB     VBP    verb, non-3rd person singular present
# مع         PROPN    NNP    noun, proper singular
# إضافات     PROPN    NNP    noun, proper singular
# وشروح      NOUN     NN     noun, singular or mass
#
#           SPACE    _SP    whitespace
# وتعليقات   PROPN    NNP    noun, proper singular
# ،          PROPN    NNP    noun, proper singular
# وأعاد      PROPN    NNP    noun, proper singular
# كتابة      PROPN    NNP    noun, proper singular
# كتاب       PROPN    NNP    noun, proper singular
# الفلك      PROPN    NNP    noun, proper singular
# الهندي     NOUN     NN     noun, singular or mass
# المعروف    NOUN     NN     noun, singular or mass
# باسم       NOUN     NN     noun, singular or mass
# "          PUNCT    ``     opening quotation mark
# السند      VERB     VBZ    verb, 3rd person singular present
# هند        PROPN    NNP    noun, proper singular
# الكبير     PROPN    NNP    noun, proper singular
# "          PUNCT    ''     closing quotation mark
# الذي       PROPN    NNP    noun, proper singular
# ترجم       NOUN     NN     noun, singular or mass
# إلى        PROPN    NNP    noun, proper singular
# اللغة      PROPN    NNP    noun, proper singular
#
#           SPACE    _SP    whitespace
# العربية    PROPN    NNP    noun, proper singular
# زمن        PROPN    NNP    noun, proper singular
# الخليفة    PROPN    NNP    noun, proper singular
# المنصور    PROPN    NNP    noun, proper singular
# فأعاد      PROPN    NNP    noun, proper singular
# الخوارزمي  PROPN    NNP    noun, proper singular
# كتابته     PROPN    NNP    noun, proper singular
# وأضاف      PROPN    NNP    noun, proper singular
# إليه       PROPN    NNP    noun, proper singular
# وسمي       PROPN    NNP    noun, proper singular
# كتابه      PROPN    NNP    noun, proper singular
# "          PUNCT    ``     opening quotation mark
# السند      VERB     VBZ    verb, 3rd person singular present
# هند        PROPN    NNP    noun, proper singular
# الصغير     PROPN    NNP    noun, proper singular
# "          PUNCT    ''     closing quotation mark
# .          PUNCT    .      punctuation mark, sentence closer
#
#
#          SPACE    _SP    whitespace
# وقد        NOUN     NN     noun, singular or mass
# عرض        NOUN     NN     noun, singular or mass
# في         INTJ     UH     interjection
# كتاب       PROPN    NNP    noun, proper singular
# المختصر    NOUN     NN     noun, singular or mass
# في         PROPN    NNP    noun, proper singular
# حساب       PROPN    NNP    noun, proper singular
# الجبر      PROPN    NNP    noun, proper singular
# والمقابلة  PROPN    NNP    noun, proper singular
# أول        PROPN    NNP    noun, proper singular
# حل         PROPN    NNP    noun, proper singular
# منهجي      PROPN    NNP    noun, proper singular
#
#           SPACE    _SP    whitespace
# للمعادلات  PROPN    NNP    noun, proper singular
# الخطية     NOUN     NN     noun, singular or mass
# والمعادلات PROPN    NNP    noun, proper singular
# التربيعية  PROPN    NNP    noun, proper singular
# مستعملا    PROPN    NNP    noun, proper singular
# في         PROPN    NNP    noun, proper singular
# ذلك        PROPN    NNP    noun, proper singular
# الطريقة    VERB     VBZ    verb, 3rd person singular present
# المعروفة   PROPN    NNP    noun, proper singular
# باسم       PROPN    NNP    noun, proper singular
# إكمال      PROPN    NNP    noun, proper singular
# المربع     NOUN     NNS    noun, plural
# .          PUNCT    .      punctuation mark, sentence closer
# ويعتبر     VERB     VB     verb, base form
# مؤسس       PROPN    NNP    noun, proper singular
# علم        PROPN    NNP    noun, proper singular
# الجبر      PROPN    NNP    noun, proper singular
# ،          PROPN    NNP    noun, proper singular
#
#           SPACE    _SP    whitespace
# (          PUNCT    -LRB-  left round bracket
# اللقب      PROPN    NNP    noun, proper singular
# الذي       PROPN    NNP    noun, proper singular
# يتقاسمه    PROPN    NNP    noun, proper singular
# مع         PROPN    NNP    noun, proper singular
# ديوفانتوس  PROPN    NNP    noun, proper singular
# )          PUNCT    -RRB-  right round bracket
# في         CCONJ    CC     conjunction, coordinating
# القرن      PROPN    NNP    noun, proper singular
# الثاني     PROPN    NNP    noun, proper singular
# عشر        PROPN    NNP    noun, proper singular
# ،          PROPN    NNP    noun, proper singular
# ولقد       PROPN    NNP    noun, proper singular
# قدمت       PROPN    NNP    noun, proper singular
# ترجمات     PROPN    NNP    noun, proper singular
# اللاتينية  PROPN    NNP    noun, proper singular
# عن         PROPN    NNP    noun, proper singular
# حسابه      PROPN    NNP    noun, proper singular
# على        PROPN    NNP    noun, proper singular
# الأرقام    PROPN    NNP    noun, proper singular
# الهندية    PROPN    NNP    noun, proper singular
# ،          PROPN    NNP    noun, proper singular
#
#           SPACE    _SP    whitespace
# النظام     PROPN    NNP    noun, proper singular
# العشري     VERB     VB     verb, base form
# إلى        PROPN    NNP    noun, proper singular
# العالم     NOUN     NNS    noun, plural
# الغربي     ADJ      JJ     adjective (English), other noun-modifier (Chinese)
# .          PUNCT    .      punctuation mark, sentence closer
# نقح        PROPN    NNP    noun, proper singular
# الخوارزمي  PROPN    NNP    noun, proper singular
# كتاب       PROPN    NNP    noun, proper singular
# الجغرافيا  PROPN    NNP    noun, proper singular
# لكلاوديوس  PROPN    NNP    noun, proper singular
# بطليموس    NOUN     NN     noun, singular or mass
# وكتب       PROPN    NNP    noun, proper singular
# في         PROPN    NNP    noun, proper singular
# علم        PROPN    NNP    noun, proper singular
# الفلك      PROPN    NNP    noun, proper singular
# والتنجيم   PROPN    NNP    noun, proper singular
# .          PUNCT    .      punctuation mark, sentence closer
#
#           SPACE    _SP    whitespace
